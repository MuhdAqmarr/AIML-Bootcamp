# %% [markdown]
# # Numpy Introduction and Usage

# %% [markdown]
# ## One Dimensional Array

# %%
import numpy as np

# %%
array1 = np.array([10,20,30,40,50])
print (array1)
# Out:
# [10 20 30 40 50]

# %% [markdown]
# ## Two Dimensional Array

# %%
array2 = np.array([[10,20,30],[40,50,60]])
print (array2)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %% [markdown]
# ## Three Dimensional Array

# %%
array3 = np.array([[[10,20,30],[40,50,60]],[[10,20,30],[40,50,60]]])
print (array3)
# Out:
# [[[10 20 30]
#   [40 50 60]]
#
#  [[10 20 30]
#   [40 50 60]]]

# %% [markdown]
# ## Find out dimension of Numpy array

# %%
print('First Array Dimension: ',array1.ndim)
# Out:
# First Array Dimension:  1

# %%
print('Second Array Dimension: ',array2.ndim)
# Out:
# Second Array Dimension:  2

# %%
print('Third Array Dimension: ',array3.ndim)
# Out:
# Third Array Dimension:  3

# %% [markdown]
# ## Write an array of 5 students marks using Numpy
# *Marks are: 80, 70, 75, 99, 89*

# %%
student_marks_array = np.array([80, 70, 75, 99, 89])
print('Array of Marks:')
print(student_marks_array)
# Out:
# Array of Marks:
# [80 70 75 99 89]

# %% [markdown]
# ## Write an array: to take Marks of 5 students in 3 subjects  using Numpy
# *Math, English, Chemistry*
#
# *[[50,45,49],[40,42,45],[35,40,46],[39,40,45],[48,40,40]]*

# %%
student_marks_3subject = np.array([[50,45,49],[40,42,45],[35,40,46],[39,40,45],[48,40,40]])
print('2D Array Example')
print(student_marks_3subject)
# Out:
# 2D Array Example
# [[50 45 49]
#  [40 42 45]
#  [35 40 46]
#  [39 40 45]
#  [48 40 40]]

# %% [markdown]
# ## Write an array: to take Marks of 4 students in 3 subjects for two semester using Numpy
#     - Students Name are: 'Amit','Sha','Xi','Arif'
#
#     - Math, English, Chemistry
#
#     - Two Semester : Sem1 , Sem2
#
#     - 4*3*2
#
#     - ([[[85, 88],[78, 82],[90, 95]] , [[76, 70],[40, 45],[90, 90]] ,[[80, 86],[78, 82],[90, 95]],[[85, 88],[78, 82],[70, 90]]])

# %%
student_marks_3subject_2sem = np.array([
    [[85, 88],[78, 82],[90, 95]],
    [[76, 70],[40, 45],[90, 90]],
    [[80, 86],[78, 82],[90, 95]],
    [[85, 88],[78, 82],[70, 90]]
])
print('3D Array Example')
print(student_marks_3subject_2sem)
# Out:
# 3D Array Example
# [[[85 88]
#   [78 82]
#   [90 95]]
#
#  [[76 70]
#   [40 45]
#   [90 90]]
#
#  [[80 86]
#   [78 82]
#   [90 95]]
#
#  [[85 88]
#   [78 82]
#   [70 90]]]

# %% [markdown]
# ## Write an array: to take wheather of 2 cities in 3 days for three times in a day morning, noon ,evening
#      - Cities Name are: Kuala Lumpur, Delhi
#      - Saturday, Sunday, Monday
#      - Three Time Slot : Morning, Noon, Evening
#      - Kuala Lumpur :[[25,30,28],[24,28,25],[30,32,30]]
#      - Delhi:[[30,35,30],[32,34,30],[28,31,30]]
#      - [[[25,30,28],[24,28,25],[30,32,30]],[[30,35,30],[32,34,30],[28,31,30]]]
# ## Create one 3 D Array for this using NumPy and print it

# %%
wheather = np.array([
    [[25,30,28],[24,28,25],[30,32,30]],
    [[30,35,30],[32,34,30],[28,31,30]]
])
print(wheather)
# Out:
# [[[25 30 28]
#   [24 28 25]
#   [30 32 30]]
#
#  [[30 35 30]
#   [32 34 30]
#   [28 31 30]]]

# %% [markdown]
# ## Basic Information
#     - shape: rows and columns
#     - Size : number of elements
#     - Dimension: return dimension 1, 2, 3....
#     - Data Type: return stored data values type
