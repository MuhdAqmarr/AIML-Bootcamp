# %% [markdown]
# # Basic Panda Example to Read out from an excel file

# %%
import pandas as pd

# %%
data_students = pd.read_excel('students.xlsx')
data_students
# Out:
#     Name  Age  Marks
# 0   John   20     85
# 1  Alice   22     90
# 2    Bob   21     78
# 3   Sara   23     92
# 4    Sam   25     90
# 5  Rohit   23     45

# %%
data_patients=pd.read_csv('D:/AIML-Bootcamp/Day-10/patients.csv')
data_patients
# Out:
#        patient_id               name  age arrival_date departure_date  \
# 0    PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1    PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2    PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3    PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4    PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
# ..            ...                ...  ...          ...            ...
# 995  PAT-a01bf534         Amber Vang   26   2025-12-02     2025-12-04
# 996  PAT-87fa07bd       Martha Smith   89   2025-11-18     2025-11-30
# 997  PAT-8f07e894     Jennifer James   72   2025-12-12     2025-12-21
# 998  PAT-4ae301e1     Kara Hernandez   47   2025-02-08     2025-02-20
# 999  PAT-e2ef9c5f    Lorraine Turner   64   2025-05-04     2025-05-08
#
#               service  satisfaction
# 0             surgery            61
# 1             surgery            83
# ...

# %%
data_patients['name']
# Out:
# 0      Richard Rodriguez
# 1         Shannon Walker
# 2           Julia Torres
# 3        Crystal Johnson
# 4            Garrett Lin
#              ...
# 995           Amber Vang
# 996         Martha Smith
# 997       Jennifer James
# 998       Kara Hernandez
# 999      Lorraine Turner
# Name: name, Length: 1000, dtype: object

# %% [markdown]
# ## Head Example

# %%
data_patients.head()
# Out:
#      patient_id               name  age arrival_date departure_date  \
# 0  PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1  PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2  PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3  PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4  PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
#
#             service  satisfaction
# 0           surgery            61
# 1           surgery            83
# 2  general_medicine            83
# 3         emergency            81
# 4               ICU            76

# %%
data_patients.head(2)
# Out:
#      patient_id               name  age arrival_date departure_date  service  \
# 0  PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22  surgery
# 1  PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14  surgery
#
#    satisfaction
# 0            61
# 1            83

# %% [markdown]
# ## Tail Example

# %%
print('Last Two Students in Excel Sheet')
data_students.tail(2)
# Out:
# Last Two Students in Excel Sheet
#     Name  Age  Marks
# 4    Sam   25     90
# 5  Rohit   23     45

# %%
data_patients.tail(5)
# Out:
#        patient_id             name  age arrival_date departure_date  \
# 995  PAT-a01bf534       Amber Vang   26   2025-12-02     2025-12-04
# 996  PAT-87fa07bd     Martha Smith   89   2025-11-18     2025-11-30
# 997  PAT-8f07e894   Jennifer James   72   2025-12-12     2025-12-21
# 998  PAT-4ae301e1   Kara Hernandez   47   2025-02-08     2025-02-20
# 999  PAT-e2ef9c5f  Lorraine Turner   64   2025-05-04     2025-05-08
#
#               service  satisfaction
# 995         emergency            91
# 996         emergency            99
# 997               ICU            69
# 998               ICU            61
# 999  general_medicine            83

# %% [markdown]
# ## Shape Example

# %%
data_patients.shape
# Out:
# (1000, 7)

# %%
data_students.shape
# Out:
# (6, 3)

# %%
# Rows and Column in Patients Sheet
rows, cols = data_patients.shape
print(f'Rows: {rows} Columns: {cols}')
# Out:
# Rows: 1000 Columns: 7

# %%
# Rows and Column in Students Sheet
rows, cols = data_students.shape
print(f'Rows: {rows} Columns: {cols}')
# Out:
# Rows: 6 Columns: 3

# %% [markdown]
# ## Values: in DataFrame

# %%
print('Student Values')
data_students.values
# Out:
# Student Values
# array([['John', 20, 85],
#        ['Alice', 22, 90],
#        ['Bob', 21, 78],
#        ['Sara', 23, 92],
#        ['Sam', 25, 90],
#        ['Rohit', 23, 45]], dtype=object)

# %%
print('Patient Values')
data_patients.values
# Out:
# Patient Values
# array([['PAT-09484753', 'Richard Rodriguez', 24, ..., '2025-03-22',
#         'surgery', 61],
#        ['PAT-f0644084', 'Shannon Walker', 6, ..., '2025-12-14',
#         'surgery', 83],
#        ['PAT-ac6162e4', 'Julia Torres', 24, ..., '2025-07-05',
#         'general_medicine', 83],
#        ...,
#        ['PAT-8f07e894', 'Jennifer James', 72, ..., '2025-12-21', 'ICU',
#         69],
#        ['PAT-4ae301e1', 'Kara Hernandez', 47, ..., '2025-02-20', 'ICU',
#         61],
#        ['PAT-e2ef9c5f', 'Lorraine Turner', 64, ..., '2025-05-08',
#         'general_medicine', 83]], dtype=object)
